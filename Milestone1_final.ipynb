# %%
d={'P1':0,'P2':0}

a=input("Player 1- Enter a letter either 'X' or 'O'...")
d['P1']=a


if d['P1'] =='X':
    d['P2']='O'
elif d['P1'] =='O':
    d['P2']='X'
print(d)
print(f"Player 1 chose {d['P1']} and Player 2 chose {d['P2']}")


def board():

    print('   |   |')

    print(' ' + d1['one'] + ' | ' + d1['two'] + ' | ' + d1['three'])

    print('   |   |')

    print('-----------')

    print('   |   |')
    print(' ' + d1['four'] + ' | ' + d1['five'] + ' | ' + d1['six'])
    print('   |   |')

    print('-----------')

    print('   |   |')

    print(' ' + d1['seven'] + ' | ' + d1['eight'] + ' | ' + d1['nine'])

    print('   |   |')
    
    
    

d1={'one':'1','two':'2','three':'3','four':'4','five':'5','six':'6','seven':'7','eight':'8','nine':'9'}
print(d1)
board();

aa=int(input("Player 1- Choose a num between 1 and 9..."))

def func(aa,count):
    #count=1
    #print("2 times")
    for k,v in d1.items():
        if v==str(aa) and (count%2!=0) and count<10:     #if aa in d1.values() and (count%2!=0):
            d1[k]=d['P1']
            print(f"Player 1 selected position {aa}")
            print(d1)
            board();
            
            if (d1['one']==d1['two']==d1['three']==d['P1']) or (d1['one']==d1['four']==d1['seven']==d['P1']) or (d1['seven']==d1['eight']==d1['nine']==d['P1']) or (d1['three']==d1['six']==d1['nine']==d['P1']) or (d1['one']==d1['five']==d1['nine']==d['P1']) or (d1['three']==d1['five']==d1['seven']==d['P1']):
                print("Player 1 won")
            else:
                if count==9:   # To avoid getting additional input, since at this stage all the colums will be filled
                    print("It's a tie!")
                    break
                else:
                    count+=1
                    b=int(input("Player 2- Choose a num between 1 and 9..."))
                    aa=b
                    func(aa,count);
                
        elif v==str(aa) and (count%2==0) and count<10:
            d1[k]=d['P2']
            print(f"Player 2 selected position {aa}")
            print(d1)
            board();
            
            if (d1['one']==d1['two']==d1['three']==d['P2']) or (d1['one']==d1['four']==d1['seven']==d['P2']) or (d1['seven']==d1['eight']==d1['nine']==d['P2']) or (d1['three']==d1['six']==d1['nine']==d['P2']) or (d1['one']==d1['five']==d1['nine']==d['P2']) or (d1['three']==d1['five']==d1['seven']==d['P2']):
                print("Player 2 won")
            else:
                count+=1
                bb=int(input("Player 1- Choose a num between 1 and 9..."))
                aa=bb
                func(aa,count);
        elif count==10:
            break
            
            


count=1      
func(aa,count);
# Out:
# Player 1- Enter a letter either 'X' or 'O'...X
# {'P1': 'X', 'P2': 'O'}
# Player 1 chose X and Player 2 chose O
# {'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'}
#    |   |
#  1 | 2 | 3
#    |   |
# -----------
#    |   |
#  4 | 5 | 6
#    |   |
# -----------
#    |   |
#  7 | 8 | 9
#    |   |
# Player 1- Choose a num between 1 and 9...6
# Player 1 selected position 6
# {'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': '9'}
#    |   |
#  1 | 2 | 3
#    |   |
# -----------
#    |   |
#  4 | 5 | X
#    |   |
# -----------
#    |   |
#  7 | 8 | 9
#    |   |
# Player 2- Choose a num between 1 and 9...9
# Player 2 selected position 9
# {'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': 'O'}
#    |   |
#  1 | 2 | 3
#    |   |
# -----------
#    |   |
#  4 | 5 | X
#    |   |
# -----------
#    |   |
#  7 | 8 | O
#    |   |
# Player 1- Choose a num between 1 and 9...1
# Player 1 selected position 1
# {'one': 'X', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': 'O'}
#    |   |
#  X | 2 | 3
#    |   |
# -----------
#    |   |
#  4 | 5 | X
#    |   |
# -----------
#    |   |
#  7 | 8 | O
#    |   |
# Player 2- Choose a num between 1 and 9...2
# Player 2 selected position 2
# {'one': 'X', 'two': 'O', 'three': '3', 'four': '4', 'five': '5', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': 'O'}
#    |   |
#  X | O | 3
#    |   |
# -----------
#    |   |
#  4 | 5 | X
#    |   |
# -----------
#    |   |
#  7 | 8 | O
#    |   |
# Player 1- Choose a num between 1 and 9...4
# Player 1 selected position 4
# {'one': 'X', 'two': 'O', 'three': '3', 'four': 'X', 'five': '5', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': 'O'}
#    |   |
#  X | O | 3
#    |   |
# -----------
#    |   |
#  X | 5 | X
#    |   |
# -----------
#    |   |
#  7 | 8 | O
#    |   |
# Player 2- Choose a num between 1 and 9...5
# Player 2 selected position 5
# {'one': 'X', 'two': 'O', 'three': '3', 'four': 'X', 'five': 'O', 'six': 'X', 'seven': '7', 'eight': '8', 'nine': 'O'}
#    |   |
#  X | O | 3
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  7 | 8 | O
#    |   |
# Player 1- Choose a num between 1 and 9...7
# Player 1 selected position 7
# {'one': 'X', 'two': 'O', 'three': '3', 'four': 'X', 'five': 'O', 'six': 'X', 'seven': 'X', 'eight': '8', 'nine': 'O'}
#    |   |
#  X | O | 3
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  X | 8 | O
#    |   |
# Player 1 won
